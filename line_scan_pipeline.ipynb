# %% [markdown]
# # STXM line-scan pipeline
#
# Interactive reduction and export for NEXAFS line scans (`.hdr`/`.xim`).
#
# Run the imports cell, then the widget cell. Use the **Dashboard** tab to browse exported spectra and run linear combination fitting (LCF). Use **Ingestion** to load line scans, set regions, normalize, and export to `experiment.parquet` and the partitioned spectrum store.
#
# Requires `uv sync` and a Jupyter kernel with the `stxm` package (`%matplotlib widget` recommended).

# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

from stxm import line_scan_processor

parent_dir = Path('/Users/hduva/Library/CloudStorage/OneDrive-SharedLibraries-WashingtonStateUniversity(email.wsu.edu)/Carbon Lab Research Group - Documents/Synchrotron Logistics and Data/ALS - Berkeley/Data/BL532/BL5321 (New STXM)')

# %%
line_scan_processor(parent_dir)
